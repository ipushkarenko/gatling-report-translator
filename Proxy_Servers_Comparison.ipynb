# %%
import pandas as pd
import matplotlib.pyplot as plt
from gtl_json_adapter import download_gtl_statistic
from single_sample_handler import plot_ok_vs_mrt
from single_sample_handler import plot_ok_ko_vs_total_requests
from single_sample_handler import parse_gtl_statistics
from single_sample_handler import print_result_table_by_name

# %%
dtos = download_gtl_statistic("/Users/ypushkarenko/Projects/milemaker-performance-tests/results", "ndriveproxysimulation")
df = parse_gtl_statistics(dtos)

# %%
plot_ok_vs_mrt(df, "PYTHON", "PYTHON: OK Requests to Mean Response Time [ms]")
plot_ok_ko_vs_total_requests(df, "PYTHON", "PYTHON: OK vs. KO to Total Number of Requests")
print_result_table_by_name(df, "PYTHON")
# Out:
#                    Name  Total requests    OK   KO  MRT[ms]
# 1   REQUEST PYTHON HOST              10    10    0      701
# 2   REQUEST PYTHON HOST              50    50    0      719
# 3   REQUEST PYTHON HOST             100   100    0     1149
# 4   REQUEST PYTHON HOST             150   150    0     1678
# 5   REQUEST PYTHON HOST             200   200    0     2063
# 6   REQUEST PYTHON HOST             250   250    0     2585
# 7   REQUEST PYTHON HOST             300   300    0     3051
# 8   REQUEST PYTHON HOST             400   400    0     3889
# 9   REQUEST PYTHON HOST             500   500    0     4862
# 10  REQUEST PYTHON HOST             600   600    0     5972
# 11  REQUEST PYTHON HOST             700   700    0     6670
# 12  REQUEST PYTHON HOST             800   800    0     7781
# 13  REQUEST PYTHON HOST             900   900    0     8598
# 14  REQUEST PYTHON HOST            1000  1000    0     9511
# 15  REQUEST PYTHON HOST            1100  1100    0    10542
# ...

# %%
plot_ok_vs_mrt(df, "NDRIVE", "NDRIVE: OK Requests to Mean Response Time [ms]")
plot_ok_ko_vs_total_requests(df, "NDRIVE", "NDRIVE: OK vs. KO to Total Number of Requests")
print_result_table_by_name(df, "NDRIVE")
# Out:
#                    Name  Total requests    OK  KO  MRT[ms]
# 1   REQUEST NDRIVE HOST              10    10   0      722
# 2   REQUEST NDRIVE HOST              50    50   0      607
# 3   REQUEST NDRIVE HOST             100   100   0      602
# 4   REQUEST NDRIVE HOST             150   150   0      617
# 5   REQUEST NDRIVE HOST             200   200   0      617
# 6   REQUEST NDRIVE HOST             250   250   0      612
# 7   REQUEST NDRIVE HOST             300   300   0      645
# 8   REQUEST NDRIVE HOST             400   400   0      621
# 9   REQUEST NDRIVE HOST             500   500   0      644
# 10  REQUEST NDRIVE HOST             600   600   0      626
# 11  REQUEST NDRIVE HOST             700   700   0      635
# 12  REQUEST NDRIVE HOST             800   800   0      625
# 13  REQUEST NDRIVE HOST             900   900   0      631
# 14  REQUEST NDRIVE HOST            1000  1000   0      632
# 15  REQUEST NDRIVE HOST            1100  1100   0      634
# ...

# %%
plot_ok_vs_mrt(df, "JAVA", "JAVA: OK Requests to Mean Response Time [ms]")
plot_ok_ko_vs_total_requests(df, "JAVA", "JAVA: OK vs. KO to Total Number of Requests")
print_result_table_by_name(df, "JAVA")
# Out:
#                  Name  Total requests    OK  KO  MRT[ms]
# 1   REQUEST JAVA HOST              10    10   0      659
# 2   REQUEST JAVA HOST              50    50   0      639
# 3   REQUEST JAVA HOST             100   100   0      653
# 4   REQUEST JAVA HOST             150   150   0      635
# 5   REQUEST JAVA HOST             200   200   0      657
# 6   REQUEST JAVA HOST             250   250   0      643
# 7   REQUEST JAVA HOST             300   300   0      663
# 8   REQUEST JAVA HOST             400   400   0      635
# 9   REQUEST JAVA HOST             500   500   0      659
# 10  REQUEST JAVA HOST             600   600   0      659
# 11  REQUEST JAVA HOST             700   700   0      649
# 12  REQUEST JAVA HOST             800   800   0      648
# 13  REQUEST JAVA HOST             900   900   0      652
# 14  REQUEST JAVA HOST            1000  1000   0      652
# 15  REQUEST JAVA HOST            1100  1100   0      659
# ...

# %%
plot_ok_vs_mrt(df, "NODEJS", "NODEJS: OK Requests to Mean Response Time [ms]")
plot_ok_ko_vs_total_requests(df, "NODEJS", "NODEJS: OK vs. KO to Total Number of Requests")
print_result_table_by_name(df, "NODEJS")
# Out:
#                    Name  Total requests    OK  KO  MRT[ms]
# 1   REQUEST NODEJS HOST              10    10   0      812
# 2   REQUEST NODEJS HOST              50    50   0      620
# 3   REQUEST NODEJS HOST             100   100   0      623
# 4   REQUEST NODEJS HOST             150   150   0      636
# 5   REQUEST NODEJS HOST             200   200   0      644
# 6   REQUEST NODEJS HOST             250   250   0      647
# 7   REQUEST NODEJS HOST             300   300   0      649
# 8   REQUEST NODEJS HOST             400   400   0      643
# 9   REQUEST NODEJS HOST             500   500   0      658
# 10  REQUEST NODEJS HOST             600   600   0      648
# 11  REQUEST NODEJS HOST             700   700   0      654
# 12  REQUEST NODEJS HOST             800   800   0      640
# 13  REQUEST NODEJS HOST             900   900   0      647
# 14  REQUEST NODEJS HOST            1000  1000   0      649
# 15  REQUEST NODEJS HOST            1100  1100   0      652
# ...
